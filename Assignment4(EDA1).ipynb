# %%
import pandas as pd
import numpy as np

# %%
data_set=pd.read_csv("C:\\Users\\91755\\Desktop\\Excelr Assignments\\EDA1\\EDA1\\Cardiotocographic.csv")
data_set
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#Step 1: Data Cleaning and Preparation

# %%
data_set.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data_set.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
data_set.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
Q1 = data_set.quantile(0.25)
Q3 = data_set.quantile(0.75)
IQR = Q3 - Q1
print("\nInterquartile Range (IQR):")
print(IQR)
# Out:
# Interquartile Range (IQR):
# LB          14.000000
# AC           0.005650
# FM           0.002567
# UC           0.004685
# DL           0.003289
# DS           0.000000
# DP           0.000000
# ASTV        29.000000
# MSTV         1.000000
# ALTV        11.000000
# MLTV         6.300000
# Width       63.000000
# Tendency     1.000000
# NSP          0.000000
# dtype: float64

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = ((data_set < lower_bound) | (data_set > upper_bound)).sum()
print("\nNumber of outliers in each column:")
print(outliers)
# Out:
# Number of outliers in each column:
# LB           10
# AC           40
# FM          347
# UC           13
# DL          125
# DS          120
# DP          284
# ASTV         10
# MSTV         80
# ALTV        318
# MLTV         81
# Width        10
# Tendency     10
# NSP         559
# dtype: int64

# %%
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    data_set[col] = np.where(data_set[col] < lower_bound[col], lower_bound[col], data_set[col])
    data_set[col] = np.where(data_set[col] > upper_bound[col], upper_bound[col], data_set[col])

# Step 4: Final Dataset Overview
print("\nDataset summary after cleaning:")
print(data_set.describe())

print("\nData cleaning and preparation completed.")
